# %% [markdown]
# Alexa

# %% [markdown]
# # 웹 사이트 순위 스크래핑

# %% [markdown]
# https://www.alexa.com/topsites

# %% [markdown]
# ## 글로벌 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = 'https://www.alexa.com/topsites'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank","Site",
                                "Daily Time on Site", "Daily Pageviews per Visitor",
                                "% of Traffic From Search","Total Sites Linking In"))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sites = soup.find_all('div',{'class':'tr site-listing'})

# %%
for site in sites:
    print(site.text)
# Out:
# 1
#
#
# Google.com
#
#
# 17:14
# 18.24
# 0.30%
# 1,300,441
#
#
# 2
#
#
# Youtube.com
#
#
# 19:08
# 10.20
# 13.80%
# 988,820
#
#
# 3
#
#
# Tmall.com
#
#
# 6:58
# 3.83
# 1.10%
# 6,212
#
#
# 4
#
#
# Qq.com
#
#
# 3:40
# 3.87
# 3.10%
# 262,198
#
#
# 5
#
#
# Baidu.com
#
#
# 5:16
# 5.10
# 7.20%
# 101,279
#
#
# 6
#
#
# Sohu.com
#
#
# 3:36
# 4.52
# 2.10%
# 25,945
#
#
# 7
#
#
# Facebook.com
#
#
# 18:40
# 8.84
# 8.90%
# 2,181,031
#
#
# 8
#
#
# Taobao.com
#
#
# 4:38
# 3.48
# 4.20%
# 24,826
#
#
# 9
#
#
# 360.cn
#
#
# 3:14
# 4.15
# 0.40%
# 14,998
#
#
# 10
#
#
# Jd.com
#
#
# 3:33
# 4.38
# 1.70%
# 8,481
#
#
# 11
#
#
# Amazon.com
#
#
# 10:41
# 9.84
# 19.60%
# 363,277
#
#
# 12
#
#
# Yahoo.com
#
#
# 5:11
# 4.76
# 8.80%
# 319,186
#
#
# 13
#
#
# Wikipedia.org
#
#
# 3:46
# 3.07
# 74.80%
# 763,999
#
#
# 14
#
#
# Weibo.com
#
#
# 2:55
# 3.48
# 2.20%
# 68,824
#
#
# 15
#
#
# Sina.com.cn
#
#
# 2:49
# 3.31
# 3.30%
# 45,672
#
#
# 16
#
#
# Zoom.us
#
#
# 7:12
# 3.61
# 14.90%
# 3,009
#
#
# 17
#
#
# Xinhuanet.com
#
#
# 3:02
# 5.87
# 2.80%
# 34,113
#
#
# 18
#
#
# Live.com
#
#
# 5:32
# 5.59
# 9.70%
# 43,223
#
#
# 19
#
#
# Reddit.com
#
#
# 5:35
# 4.44
# 37.10%
# 163,041
#
#
# 20
#
#
# Netflix.com
#
#
# 4:45
# 3.33
# 9.40%
# 10,865
#
#
# 21
#
#
# Microsoft.com
#
#
# 4:34
# 3.40
# 27.70%
# 235,680
#
#
# 22
#
#
# Instagram.com
#
#
# 8:51
# 10.46
# 14.80%
# 622,099
#
#
# 23
#
#
# Office.com
#
#
# 12:24
# 10.92
# 6.30%
# 5,767
#
#
# 24
#
#
# Panda.tv
#
#
# 2:51
# 5.44
# 0.70%
# 340
#
#
# 25
#
#
# Zhanqi.tv
#
#
# 2:52
# 5.44
# 0.90%
# 334
#
#
# 26
#
#
# Google.com.hk
#
#
# 4:34
# 5.72
# 2.70%
# 9,758
#
#
# 27
#
#
# Alipay.com
#
#
# 3:10
# 3.30
# 1.50%
# 3,513
#
#
# 28
#
#
# Csdn.net
#
#
# 3:21
# 4.90
# 9.50%
# 6,438
#
#
# 29
#
#
# Bing.com
#
#
# 2:56
# 2.68
# 5.40%
# 41,693
#
#
# 30
#
#
# Vk.com
#
#
# 7:02
# 3.62
# 9.30%
# 124,054
#
#
# 31
#
#
# Myshopify.com
#
#
# 21:02
# 13.41
# 3.10%
# 118
#
#
# 32
#
#
# Yahoo.co.jp
#
#
# 9:57
# 9.16
# 14.30%
# 57,560
#
#
# 33
#
#
# Microsoftonline.com
#
#
# 1:03
# 1.87
# 2.80%
# 677
#
#
# 34
#
#
# Naver.com
#
#
# 14:48
# 12.20
# 10.20%
# 38,994
#
#
# 35
#
#
# Bongacams.com
#
#
# 3:12
# 1.65
# 6.90%
# 178,712
#
#
# 36
#
#
# Twitch.tv
#
#
# 8:33
# 4.12
# 7.30%
# 9,771
#
#
# 37
#
#
# Okezone.com
#
#
# 4:01
# 4.21
# 6.50%
# 10,399
#
#
# 38
#
#
# Twitter.com
#
#
# 12:48
# 10.40
# 11.70%
# 1,578,393
#
#
# 39
#
#
# Ebay.com
#
#
# 9:43
# 7.75
# 18.10%
# 74,970
#
#
# 40
#
#
# Adobe.com
#
#
# 3:43
# 3.52
# 22.10%
# 244,100
#
#
# 41
#
#
# Huanqiu.com
#
#
# 2:51
# 5.23
# 1.30%
# 6,324
#
#
# 42
#
#
# Tianya.cn
#
#
# 2:54
# 5.13
# 0.70%
# 5,200
#
#
# 43
#
#
# Yy.com
#
#
# 2:48
# 5.25
# 0.90%
# 2,120
#
#
# 44
#
#
# Amazon.in
#
#
# 12:22
# 10.41
# 24.00%
# 6,673
#
#
# 45
#
#
# Aliexpress.com
#
#
# 9:59
# 8.29
# 15.40%
# 18,807
#
#
# 46
#
#
# Amazon.co.jp
#
#
# 8:05
# 9.25
# 19.60%
# 48,782
#
#
# 47
#
#
# 17ok.com
#
#
# 2:15
# 3.99
# 0.70%
# 368
#
#
# 48
#
#
# Canva.com
#
#
# 7:45
# 4.45
# 16.40%
# 2,376
#
#
# 49
#
#
# Linkedin.com
#
#
# 11:07
# 9.11
# 14.50%
# 608,654
#
#
# 50
#
#
# Chaturbate.com
#
#
# 11:15
# 8.28
# 8.60%
# 156,661

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for site in sites:
    rank = site.find('div', {'class':'td'}).get_text()
    website = site.select('p>a')[0].get_text()
    infos = site.find_all('div', {'class': 'td right'})
    time = infos[0].get_text()
    pageview=infos[1].get_text()
    traffic=infos[2].get_text()
    linking=infos[3].get_text()
    rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.30%              1,300,441
# 2     2          Youtube.com  ...                   13.80%                988,820
# 3     3            Tmall.com  ...                    1.10%                  6,212
# 4     4               Qq.com  ...                    3.10%                262,198
# 5     5            Baidu.com  ...                    7.20%                101,279
# 6     6             Sohu.com  ...                    2.10%                 25,945
# 7     7         Facebook.com  ...                    8.90%              2,181,031
# 8     8           Taobao.com  ...                    4.20%                 24,826
# 9     9               360.cn  ...                    0.40%                 14,998
# 10   10               Jd.com  ...                    1.70%                  8,481
# 11   11           Amazon.com  ...                   19.60%                363,277
# 12   12            Yahoo.com  ...                    8.80%                319,186
# 13   13        Wikipedia.org  ...                   74.80%                763,999
# 14   14            Weibo.com  ...                    2.20%                 68,824
# 15   15          Sina.com.cn  ...                    3.30%                 45,672
# 16   16              Zoom.us  ...                   14.90%                  3,009
# 17   17        Xinhuanet.com  ...                    2.80%                 34,113
# 18   18             Live.com  ...                    9.70%                 43,223
# 19   19           Reddit.com  ...                   37.10%                163,041
# 20   20          Netflix.com  ...                    9.40%                 10,865
# 21   21        Microsoft.com  ...                   27.70%                235,680
# 22   22        Instagram.com  ...                   14.80%                622,099
# 23   23           Office.com  ...                    6.30%                  5,767
# 24   24             Panda.tv  ...                    0.70%                    340
# 25   25            Zhanqi.tv  ...                    0.90%                    334
# 26   26        Google.com.hk  ...                    2.70%                  9,758
# 27   27           Alipay.com  ...                    1.50%                  3,513
# 28   28             Csdn.net  ...                    9.50%                  6,438
# 29   29             Bing.com  ...                    5.40%                 41,693
# 30   30               Vk.com  ...                    9.30%                124,054
# 31   31        Myshopify.com  ...                    3.10%                    118
# 32   32          Yahoo.co.jp  ...                   14.30%                 57,560
# 33   33  Microsoftonline.com  ...                    2.80%                    677
# 34   34            Naver.com  ...                   10.20%                 38,994
# 35   35        Bongacams.com  ...                    6.90%                178,712
# 36   36            Twitch.tv  ...                    7.30%                  9,771
# 37   37          Okezone.com  ...                    6.50%                 10,399
# 38   38          Twitter.com  ...                   11.70%              1,578,393
# 39   39             Ebay.com  ...                   18.10%                 74,970
# 40   40            Adobe.com  ...                   22.10%                244,100
# 41   41          Huanqiu.com  ...                    1.30%                  6,324
# 42   42            Tianya.cn  ...                    0.70%                  5,200
# 43   43               Yy.com  ...                    0.90%                  2,120
# 44   44            Amazon.in  ...                   24.00%                  6,673
# 45   45       Aliexpress.com  ...                   15.40%                 18,807
# 46   46         Amazon.co.jp  ...                   19.60%                 48,782
# 47   47             17ok.com  ...                    0.70%                    368
# 48   48            Canva.com  ...                   16.40%                  2,376
# 49   49         Linkedin.com  ...                   14.50%                608,654
# 50   50       Chaturbate.com  ...                    8.60%                156,661
#
# [50 rows x 6 columns]

# %% [markdown]
# ## 미국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = 'https://www.alexa.com/topsites/countries/US'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank","Site",
                                "Daily Time on Site", "Daily Pageviews per Visitor",
                                "% of Traffic From Search","Total Sites Linking In"))

sites = soup.find_all('div',{'class':'tr site-listing'})

for site in sites:
    rank = site.find('div', {'class':'td'}).get_text()
    website = site.select('p>a')[0].get_text()
    infos = site.find_all('div', {'class': 'td right'})
    time = infos[0].get_text()
    pageview=infos[1].get_text()
    traffic=infos[2].get_text()
    linking=infos[3].get_text()
    rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.30%              1,300,441
# 2     2          Youtube.com  ...                   13.80%                988,820
# 3     3           Amazon.com  ...                   19.60%                363,277
# 4     4            Yahoo.com  ...                    8.80%                319,186
# 5     5         Facebook.com  ...                    8.90%              2,181,031
# 6     6              Zoom.us  ...                   14.90%                  3,009
# 7     7           Reddit.com  ...                   37.10%                163,041
# 8     8             Bing.com  ...                    5.40%                 41,693
# 9     9        Wikipedia.org  ...                   74.80%                763,999
# 10   10        Myshopify.com  ...                    3.10%                    118
# 11   11             Ebay.com  ...                   18.10%                 74,970
# 12   12           Office.com  ...                    6.30%                  5,767
# 13   13            Chase.com  ...                    8.50%                  1,231
# 14   14            Force.com  ...                    2.70%                  3,221
# 15   15             Live.com  ...                    9.70%                 43,223
# 16   16        Microsoft.com  ...                   27.70%                235,680
# 17   17          Netflix.com  ...                    9.40%                 10,865
# 18   18        Instagram.com  ...                   14.80%                622,099
# 19   19           Zillow.com  ...                   31.90%                  9,152
# 20   20            Twitch.tv  ...                    7.30%                  9,771
# 21   21  Microsoftonline.com  ...                    2.80%                    677
# 22   22       Salesforce.com  ...                    6.40%                  4,649
# 23   23          Walmart.com  ...                   26.80%                 18,141
# 24   24             Etsy.com  ...                   18.40%                101,832
# 25   25         Linkedin.com  ...                   14.50%                608,654
# 26   26       Chaturbate.com  ...                    8.60%                156,661
# 27   27           Indeed.com  ...                   27.40%                  7,630
# 28   28          Dropbox.com  ...                    8.50%                 22,306
# 29   29            Adobe.com  ...                   22.10%                244,100
# 30   30          Twitter.com  ...                   11.70%              1,578,393
# 31   31             Espn.com  ...                   13.70%                  9,008
# 32   32           Intuit.com  ...                   13.30%                  6,363
# 33   33             Okta.com  ...                    2.90%                    255
# 34   34       Wellsfargo.com  ...                   10.50%                  2,218
# 35   35              Cnn.com  ...                   20.10%                114,281
# 36   36            Apple.com  ...                   36.80%                174,917
# 37   37          Nytimes.com  ...                   28.80%                163,756
# 38   38       Craigslist.org  ...                   21.90%                 14,958
# 39   39        Homedepot.com  ...                   42.90%                 11,948
# 40   40            Slack.com  ...                    5.00%                  1,374
# 41   41       Aliexpress.com  ...                   15.40%                 18,807
# 42   42             Hulu.com  ...                   10.00%                 11,245
# 43   43            Canva.com  ...                   16.40%                  2,376
# 44   44              Msn.com  ...                    5.10%                 97,844
# 45   45            Tmall.com  ...                    1.10%                  6,212
# 46   46      Instructure.com  ...                    8.80%                  1,034
# 47   47             Imdb.com  ...                   49.90%                137,215
# 48   48       Capitalone.com  ...                   12.50%                  1,083
# 49   49           Paypal.com  ...                    8.20%                 16,257
# 50   50             Usps.com  ...                   22.60%                  7,840
#
# [50 rows x 6 columns]

# %% [markdown]
# ## 한국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = 'https://www.alexa.com/topsites/countries/KR'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank","Site",
                                "Daily Time on Site", "Daily Pageviews per Visitor",
                                "% of Traffic From Search","Total Sites Linking In"))

sites = soup.find_all('div',{'class':'tr site-listing'})

for site in sites:
    rank = site.find('div', {'class':'td'}).get_text()
    website = site.select('p>a')[0].get_text()
    infos = site.find_all('div', {'class': 'td right'})
    time = infos[0].get_text()
    pageview=infos[1].get_text()
    traffic=infos[2].get_text()
    linking=infos[3].get_text()
    rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank            Site  ... % of Traffic From Search Total Sites Linking In
# 1     1      Google.com  ...                    0.30%              1,300,441
# 2     2       Naver.com  ...                   10.20%                 38,994
# 3     3     Youtube.com  ...                   13.80%                988,820
# 4     4        Daum.net  ...                    4.40%                 15,145
# 5     5     Tistory.com  ...                   26.00%                 10,601
# 6     6       Kakao.com  ...                    7.10%                 11,869
# 7     7       Tmall.com  ...                    1.10%                  6,212
# 8     8     Coupang.com  ...                   12.30%                    392
# 9     9      Amazon.com  ...                   19.60%                363,277
# 10   10    Google.co.kr  ...                   12.30%                  6,241
# 11   11       Namu.wiki  ...                   18.50%                    104
# 12   12    Facebook.com  ...                    8.90%              2,181,031
# 13   13     Netflix.com  ...                    9.40%                 10,865
# 14   14   Wikipedia.org  ...                   74.80%                763,999
# 15   15        Sohu.com  ...                    2.10%                 25,945
# 16   16          Qq.com  ...                    3.10%                262,198
# 17   17      Taobao.com  ...                    4.20%                 24,826
# 18   18          360.cn  ...                    0.40%                 14,998
# 19   19          Jd.com  ...                    1.70%                  8,481
# 20   20       Baidu.com  ...                    7.20%                101,279
# 21   21   Microsoft.com  ...                   27.70%                235,680
# 22   22   Instagram.com  ...                   14.80%                622,099
# 23   23    Dcinside.com  ...                   21.30%                    735
# 24   24       Yahoo.com  ...                    8.80%                319,186
# 25   25       Adobe.com  ...                   22.10%                244,100
# 26   26         Zoom.us  ...                   14.90%                  3,009
# 27   27      11st.co.kr  ...                    3.00%                  1,203
# 28   28       Donga.com  ...                   15.60%                  4,204
# 29   29       Upbit.com  ...                    7.40%                    107
# 30   30        Nate.com  ...                    7.50%                  2,219
# 31   31      Office.com  ...                    6.30%                  5,767
# 32   32      Chosun.com  ...                   27.00%                  7,512
# 33   33   Gmarket.co.kr  ...                   17.90%                  2,500
# 34   34       Twitch.tv  ...                    7.30%                  9,771
# 35   35     Sina.com.cn  ...                    3.30%                 45,672
# 36   36       Weibo.com  ...                    2.20%                 68,824
# 37   37      Danawa.com  ...                   30.70%                  1,285
# 38   38     Fmkorea.com  ...                   15.60%                    795
# 39   39        Bing.com  ...                    5.40%                 41,693
# 40   40       Apple.com  ...                   36.80%                174,917
# 41   41        Ebay.com  ...                   18.10%                 74,970
# 42   42   Auction.co.kr  ...                   11.20%                  1,352
# 43   43   Afreecatv.com  ...                    8.00%                    495
# 44   44      Reddit.com  ...                   37.10%                163,041
# 45   45       Joins.com  ...                   23.70%                  5,369
# 46   46       Yna.co.kr  ...                   15.90%                    567
# 47   47    Nicovideo.jp  ...                   12.70%                 12,317
# 48   48    Amazon.co.uk  ...                   14.40%                 56,938
# 49   49  Aliexpress.com  ...                   15.40%                 18,807
# 50   50  Jobkorea.co.kr  ...                   30.70%                  1,016
#
# [50 rows x 6 columns]
